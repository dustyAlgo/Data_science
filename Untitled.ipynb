# %%
import pandas as pd

# %%
df = pd.DataFrame([{"Biology":90, "neuroscience":65},{"Biology" : 77, "neuroscience":89}])
df
# Out:
#    Biology  neuroscience
# 0       90            65
# 1       77            89

# %%
covid_data = pd.read_csv("countries-aggregated.csv")

# %%
covid_data.head()
# Out:
#          Date      Country  Confirmed  Recovered  Deaths
# 0  2020-01-22  Afghanistan          0          0       0
# 1  2020-01-23  Afghanistan          0          0       0
# 2  2020-01-24  Afghanistan          0          0       0
# 3  2020-01-25  Afghanistan          0          0       0
# 4  2020-01-26  Afghanistan          0          0       0

# %%
covid_data.info()  #check missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161568 entries, 0 to 161567
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Date       161568 non-null  object
#  1   Country    161568 non-null  object
#  2   Confirmed  161568 non-null  int64
#  3   Recovered  161568 non-null  int64
#  4   Deaths     161568 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 6.2+ MB

# %%
covid_idx_con = covid_data.set_index("Country") # setting Country column as new index

# %%
covid_idx_con
# Out:
#                    Date  Confirmed  Recovered  Deaths
# Country
# Afghanistan  2020-01-22          0          0       0
# Afghanistan  2020-01-23          0          0       0
# Afghanistan  2020-01-24          0          0       0
# Afghanistan  2020-01-25          0          0       0
# Afghanistan  2020-01-26          0          0       0
# ...                 ...        ...        ...     ...
# Zimbabwe     2022-04-12     247094          0    5460
# Zimbabwe     2022-04-13     247160          0    5460
# Zimbabwe     2022-04-14     247208          0    5462
# Zimbabwe     2022-04-15     247237          0    5462
# Zimbabwe     2022-04-16     247237          0    5462
#
# [161568 rows x 4 columns]

# %%
covid_idx_con.loc["Afghanistan"] # accessing element through new index
# Out:
#                    Date  Confirmed  Recovered  Deaths
# Country
# Afghanistan  2020-01-22          0          0       0
# Afghanistan  2020-01-23          0          0       0
# Afghanistan  2020-01-24          0          0       0
# Afghanistan  2020-01-25          0          0       0
# Afghanistan  2020-01-26          0          0       0
# ...                 ...        ...        ...     ...
# Afghanistan  2022-04-12     178257          0    7676
# Afghanistan  2022-04-13     178295          0    7676
# Afghanistan  2022-04-14     178352          0    7676
# Afghanistan  2022-04-15     178373          0    7676
# Afghanistan  2022-04-16     178387          0    7676
#
# [816 rows x 4 columns]

# %%
covid_idx_con.reset_index()
# Out:
#             Country        Date  Confirmed  Recovered  Deaths
# 0       Afghanistan  2020-01-22          0          0       0
# 1       Afghanistan  2020-01-23          0          0       0
# 2       Afghanistan  2020-01-24          0          0       0
# 3       Afghanistan  2020-01-25          0          0       0
# 4       Afghanistan  2020-01-26          0          0       0
# ...             ...         ...        ...        ...     ...
# 161563     Zimbabwe  2022-04-12     247094          0    5460
# 161564     Zimbabwe  2022-04-13     247160          0    5460
# 161565     Zimbabwe  2022-04-14     247208          0    5462
# 161566     Zimbabwe  2022-04-15     247237          0    5462
# 161567     Zimbabwe  2022-04-16     247237          0    5462
#
# [161568 rows x 5 columns]

# %%
mask = covid_idx_con["Confirmed"] > 240000 # creating mask
mask
# Out:
# Country
# Afghanistan    False
# Afghanistan    False
# Afghanistan    False
# Afghanistan    False
# Afghanistan    False
#                ...
# Zimbabwe        True
# Zimbabwe        True
# Zimbabwe        True
# Zimbabwe        True
# Zimbabwe        True
# Name: Confirmed, Length: 161568, dtype: bool

# %%
filtered_data = covid_idx_con[mask]  # applying the mask to dataset
filtered_data
# Out:
#                 Date  Confirmed  Recovered  Deaths
# Country
# Albania   2022-01-20     241512          0    3286
# Albania   2022-01-21     244182          0    3292
# Albania   2022-01-22     246412          0    3297
# Albania   2022-01-23     248070          0    3305
# Albania   2022-01-24     248070          0    3305
# ...              ...        ...        ...     ...
# Zimbabwe  2022-04-12     247094          0    5460
# Zimbabwe  2022-04-13     247160          0    5460
# Zimbabwe  2022-04-14     247208          0    5462
# Zimbabwe  2022-04-15     247237          0    5462
# Zimbabwe  2022-04-16     247237          0    5462
#
# [41685 rows x 4 columns]

# %%
#Applying groupby to calculate total Confirmed cases in each country
covid_idx_date = covid_data.groupby("Country")[['Confirmed']].sum()

# %%
covid_idx_date
# Out:
#                       Confirmed
# Country
# Afghanistan            66031705
# Albania                82385140
# Algeria                94695072
# Andorra                 9598486
# Angola                 26425596
# ...                         ...
# West Bank and Gaza    187339576
# Winter Olympics 2022      39517
# Yemen                   3987738
# Zambia                 87545852
# Zimbabwe               56346213
#
# [198 rows x 1 columns]

# %%
data = {
    "Name": ["Amit", "Riya", "Karan", "Neha"],
    "Age": [22, 25, 19, 28],
    "Score": [85, 67, 90, 76]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age  Score
# 0   Amit   22     85
# 1   Riya   25     67
# 2  Karan   19     90
# 3   Neha   28     76

# %%
world_covid_data = pd.read_csv("worldwide-aggregate.csv")

# %%
world_covid_data.head()
# Out:
#          Date  Confirmed  Recovered  Deaths  Increase rate
# 0  2020-01-22        557         30      17            NaN
# 1  2020-01-23        657         32      18      17.953321
# 2  2020-01-24        944         39      26      43.683409
# 3  2020-01-25       1437         42      42      52.224576
# 4  2020-01-26       2120         56      56      47.529576

# %%
result = pd.merge(covid_data, world_covid_data, on="Date", how ="inner")
result
# Out:
#               Date      Country  Confirmed_x  Recovered_x  Deaths_x  \
# 0       2020-01-22  Afghanistan            0            0         0
# 1       2020-01-23  Afghanistan            0            0         0
# 2       2020-01-24  Afghanistan            0            0         0
# 3       2020-01-25  Afghanistan            0            0         0
# 4       2020-01-26  Afghanistan            0            0         0
# ...            ...          ...          ...          ...       ...
# 161563  2022-04-12     Zimbabwe       247094            0      5460
# 161564  2022-04-13     Zimbabwe       247160            0      5460
# 161565  2022-04-14     Zimbabwe       247208            0      5462
# 161566  2022-04-15     Zimbabwe       247237            0      5462
# 161567  2022-04-16     Zimbabwe       247237            0      5462
#
#         Confirmed_y  Recovered_y  Deaths_y  Increase rate
# 0               557           30        17            NaN
# ...

# %%
result_cut = result.iloc[1:100,1::2]  # slicing rows and column within iloc
result_cut
# Out:
#         Country  Recovered_x  Confirmed_y  Deaths_y
# 1   Afghanistan            0          657        18
# 2   Afghanistan            0          944        26
# 3   Afghanistan            0         1437        42
# 4   Afghanistan            0         2120        56
# 5   Afghanistan            0         2929        82
# ..          ...          ...          ...       ...
# 95  Afghanistan          207      2969606    216860
# 96  Afghanistan          220      3040528    221730
# 97  Afghanistan          228      3116384    228524
# 98  Afghanistan          252      3193728    235484
# 99  Afghanistan          260      3277569    241546
#
# [99 rows x 4 columns]

# %%
# Image manipulation: OpenCV and Matplotlib

# %%
import cv2

# %%
image = cv2.imread("image1.jpg")

# %%
image.shape
# Out:
# (527, 527, 3)

# %%
img = cv2.imread("image1.jpg")
img0 = cv2.imread("image.jpg")
cv2.imshow("My Image", img)

print("Press any key to close the window")
cv2.waitKey(0)  # Wait indefinitely
cv2.destroyAllWindows()
# Out:
# Press any key to close the window

# %%
import numpy as np

# %%
# Increasing brightness
bright_mat = np.ones(img.shape, dtype = 'uint8') * 50

# %%
brighter = cv2.add(bright_mat,img)
cv2.imshow("My Image", brighter)

print("Press any key to close the window")
cv2.waitKey(0)  # Wait indefinitely
cv2.destroyAllWindows()
# Out:
# Press any key to close the window

# %%
# Converting image to HSV and doing manipulation
img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# %%
hue, sat, val = cv2.split(img_hsv) #splitting into channels

# %%
# doing manipulations
val = cv2.add(val, 25)
sat  = cv2.add(sat, 25)
hue = cv2.add(hue, 25)
hsv_edited = cv2.merge((hue,sat,val))
edited = cv2.cvtColor(hsv_edited, cv2.COLOR_HSV2BGR)

# %%
cv2.imshow("My Image", edited)

print("Press any key to close the window")
cv2.waitKey(0)  # Wait indefinitely
cv2.destroyAllWindows()
# Out:
# Press any key to close the window

# %%
# Resize image to fit screen (e.g., scale down by half)
scale_percent = 50  # percent of original size
width = int(img.shape[1] * scale_percent / 100)
height = int(img.shape[0] * scale_percent / 100)
dim = (width, height)

resized = cv2.resize(img, dim, interpolation=cv2.INTER_AREA)

cv2.imshow("My Image", resized)

print("Press any key to close the window")
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Press any key to close the window

# %%
import pyautogui #using python auto gui
screen_width, screen_height = pyautogui.size()
height, width = img.shape[:2]

scale_width = screen_width / width
scale_height = screen_height / height
scale = min(scale_width, scale_height) * 0.9  # leave some padding

new_width = int(width * scale)
new_height = int(height * scale)

resized = cv2.resize(img, (new_width, new_height), interpolation=cv2.INTER_AREA)

cv2.imshow("My Image", resized)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 import pyautogui #using python auto gui
#       2 screen_width, screen_height = pyautogui.size()
#       3 height, width = img.shape[:2]
#
# ModuleNotFoundError: No module named 'pyautogui'

# %%
# Converting image color dimensions: BGR, RGB, HSV
from matplotlib import pyplot as plt
imagergb=cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(imagergb)

# %%
imagegray = cv2.cvtColor(resized, cv2.COLOR_BGR2GRAY) # converting to Gray scale
cv2.imshow('Gray Scale',imagegray)
cv2.waitKey(0)
cv2.destroyAllWindows()
